# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.signal import savgol_filter
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply, Conv2D, Concatenate, Activation, Add, Input, Flatten, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionResNetV2


def read_multiclass_data(base_path):
    data = {}
    all_images, all_labels = [], []
    label_map = {}
    for zoom_level in os.listdir(base_path):
        zoom_path = os.path.join(base_path, zoom_level)
        if os.path.isdir(zoom_path):
            data[zoom_level] = {}
            for class_index, class_name in enumerate(os.listdir(zoom_path)):
                class_path = os.path.join(zoom_path, class_name)
                if os.path.isdir(class_path):
                    label_map[class_name] = class_index
                    image_paths = [
                        os.path.join(class_path, f)
                        for f in os.listdir(class_path)
                        if f.endswith(('.png', '.jpg', '.jpeg'))
                    ]
                    data[zoom_level][class_name] = image_paths
                    all_images.extend(image_paths)
                    all_labels.extend([class_index] * len(image_paths))
    return data, all_images, all_labels, label_map


def balance_dataset(image_paths, labels):
    class_distribution = defaultdict(int)
    for label in labels:
        class_distribution[label] += 1
    mean_count = np.mean(list(class_distribution.values()))

    balanced_image_paths, balanced_labels = [], []
    for class_id in class_distribution:
        class_indices = [i for i, label in enumerate(labels) if label == class_id]
        class_images = [image_paths[i] for i in class_indices]
        if class_distribution[class_id] < mean_count:
            oversampled_images = np.random.choice(class_images, size=int(mean_count - class_distribution[class_id]), replace=True)
            balanced_image_paths.extend(class_images + list(oversampled_images))
            balanced_labels.extend([class_id] * len(class_images + list(oversampled_images)))
        else:
            undersampled_images = np.random.choice(class_images, size=int(mean_count), replace=False)
            balanced_image_paths.extend(list(undersampled_images))
            balanced_labels.extend([class_id] * len(undersampled_images))
    return balanced_image_paths, balanced_labels


class CBAM(Layer):
    def __init__(self, reduction_ratio=16):
        super(CBAM, self).__init__()
        self.reduction_ratio = reduction_ratio

    def build(self, input_shape):
        channel = input_shape[-1]
        self.shared_dense_one = Dense(channel // self.reduction_ratio, activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
        self.shared_dense_two = Dense(channel, kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
        self.conv2d = Conv2D(filters=1, kernel_size=7, strides=1, padding='same', activation='sigmoid', kernel_initializer='he_normal', use_bias=False)

    def call(self, input_feature):

        avg_pool = GlobalAveragePooling2D()(input_feature)
        avg_pool = Reshape((1, 1, input_feature.shape[-1]))(avg_pool)
        avg_pool = self.shared_dense_one(avg_pool)
        avg_pool = self.shared_dense_two(avg_pool)
        max_pool = GlobalMaxPooling2D()(input_feature)
        max_pool = Reshape((1, 1, input_feature.shape[-1]))(max_pool)
        max_pool = self.shared_dense_one(max_pool)
        max_pool = self.shared_dense_two(max_pool)
        channel_attention = Activation('sigmoid')(Add()([avg_pool, max_pool]))
        channel_refined = Multiply()([input_feature, channel_attention])
        # Spatial Attention
        avg_pool = tf.reduce_mean(channel_refined, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(channel_refined, axis=-1, keepdims=True)
        concat = Concatenate(axis=-1)([avg_pool, max_pool])
        spatial_attention = self.conv2d(concat)
        refined_feature = Multiply()([channel_refined, spatial_attention])
        return refined_feature


def build_model_with_cbam(input_shape=(224, 224, 3), num_classes=8):
    base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = True
    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = CBAM()(x)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    return Model(inputs, outputs)


def apply_clahe_to_color_image(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    ca = clahe.apply(a)
    cb = clahe.apply(b)
    lab = cv2.merge((cl, ca, cb))
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

def preprocess_image(image_path, target_size, augment=False, apply_clahe=False):
    image = cv2.imread(image_path.decode('utf-8'))
    if apply_clahe:
        image = apply_clahe_to_color_image(image)
    image = cv2.resize(image, target_size)
    image = image.astype('float32') / 255.0
    if augment:
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_flip_up_down(image)
    return image

def preprocess_image_wrapper(image_path, label, target_size, augment, apply_clahe):
    def _preprocess(path):
        return preprocess_image(path, target_size, augment, apply_clahe)
    image = tf.numpy_function(_preprocess, inp=[image_path], Tout=tf.float32)
    image.set_shape((*target_size, 3))
    return image, label


def create_dataset(image_paths, labels, batch_size=32, target_size=(224, 224), augment=False, apply_clahe=False):
    labels = to_categorical(labels, num_classes=len(set(labels)))
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(
        lambda x, y: preprocess_image_wrapper(x, y, target_size, augment, apply_clahe),
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset


def main():
    base_path = "/kaggle/input/breakhis-breast-cancer-histopathological-dataset/BreakHis - Breast Cancer Histopathological Database/dataset_cancer_v1/dataset_cancer_v1/classificacao_multiclasse"


    multiclass_data, all_images, all_labels, label_map = read_multiclass_data(base_path)
    balanced_paths, balanced_labels = balance_dataset(all_images, all_labels)


    train_paths, temp_paths, train_labels, temp_labels = train_test_split(
        balanced_paths, balanced_labels, test_size=0.3, random_state=42, stratify=balanced_labels)
    val_paths, test_paths, val_labels, test_labels = train_test_split(
        temp_paths, temp_labels, test_size=0.5, random_state=42, stratify=temp_labels)


    train_dataset = create_dataset(train_paths, train_labels, augment=True, apply_clahe=True)
    val_dataset = create_dataset(val_paths, val_labels, apply_clahe=True)
    test_dataset = create_dataset(test_paths, test_labels, apply_clahe=True)


    model = build_model_with_cbam(num_classes=len(label_map))
    model.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )


    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)


    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=50,
        callbacks=[early_stopping, lr_scheduler]
    )


    y_pred = model.predict(test_dataset)
    y_true = np.array(test_labels)
    y_true = y_true.argmax(axis=1) if y_true.ndim > 1 else y_true
    y_pred = y_pred.argmax(axis=1)
    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=label_map.keys()))


    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()


    with open('/kaggle/working/model.tflite', 'wb') as f:
        f.write(tflite_model)
    print("TFLite model saved to /kaggle/working/model.tflite")

if __name__ == "__main__":
    main()
# Out:
# 2025-06-23 08:28:14.099617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750667294.612635      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750667294.746040      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1750667316.778379      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750667316.779158      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750667464.861779     112 service.cc:148] XLA service 0x7a46a0003470 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750667464.863604     112 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750667464.863624     112 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750667479.176920     112 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1750667533.958764     112 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.1328 - loss: 2.6301 - precision: 0.1660 - recall: 0.0375 - val_accuracy: 0.1594 - val_loss: 26.8253 - val_precision: 0.1537 - val_recall: 0.0784 - learning_rate: 0.0010
# Epoch 2/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.1330 - loss: 2.3507 - precision: 0.1885 - recall: 0.0180 - val_accuracy: 0.1248 - val_loss: 2.0982 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.1517 - loss: 2.2339 - precision: 0.2270 - recall: 0.0121 - val_accuracy: 0.1636 - val_loss: 2.0618 - val_precision: 0.6000 - val_recall: 0.0051 - learning_rate: 0.0010
# Epoch 4/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.2521 - loss: 1.9375 - precision: 0.4836 - recall: 0.0472 - val_accuracy: 0.3170 - val_loss: 2.4843 - val_precision: 0.5035 - val_recall: 0.0607 - learning_rate: 0.0010
# Epoch 5/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 657ms/step - accuracy: 0.3209 - loss: 1.7703 - precision: 0.5747 - recall: 0.0815 - val_accuracy: 0.1256 - val_loss: 42.6449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.3570 - loss: 1.6652 - precision: 0.6165 - recall: 0.0940 - val_accuracy: 0.3331 - val_loss: 1.5988 - val_precision: 0.8500 - val_recall: 0.0717 - learning_rate: 0.0010
# Epoch 7/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 655ms/step - accuracy: 0.3982 - loss: 1.5448 - precision: 0.6617 - recall: 0.1422 - val_accuracy: 0.2175 - val_loss: 3.2755 - val_precision: 0.2059 - val_recall: 0.0118 - learning_rate: 0.0010
# Epoch 8/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 656ms/step - accuracy: 0.4440 - loss: 1.4558 - precision: 0.6879 - recall: 0.1732 - val_accuracy: 0.1922 - val_loss: 1.9636 - val_precision: 1.0000 - val_recall: 0.0067 - learning_rate: 0.0010
# Epoch 9/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 655ms/step - accuracy: 0.4594 - loss: 1.4484 - precision: 0.6631 - recall: 0.1799 - val_accuracy: 0.2142 - val_loss: 17.4737 - val_precision: 0.1534 - val_recall: 0.0826 - learning_rate: 0.0010
# Epoch 10/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 661ms/step - accuracy: 0.4934 - loss: 1.3380 - precision: 0.6900 - recall: 0.2186 - val_accuracy: 0.4924 - val_loss: 1.3395 - val_precision: 0.8107 - val_recall: 0.1408 - learning_rate: 5.0000e-04
# Epoch 11/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.5231 - loss: 1.2421 - precision: 0.6898 - recall: 0.2670 - val_accuracy: 0.5211 - val_loss: 1.3195 - val_precision: 0.6806 - val_recall: 0.2479 - learning_rate: 5.0000e-04
# Epoch 12/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.5609 - loss: 1.1774 - precision: 0.6968 - recall: 0.3235 - val_accuracy: 0.5093 - val_loss: 1.3305 - val_precision: 0.6622 - val_recall: 0.2943 - learning_rate: 5.0000e-04
# Epoch 13/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.5838 - loss: 1.1069 - precision: 0.7128 - recall: 0.3838 - val_accuracy: 0.6290 - val_loss: 0.9972 - val_precision: 0.7451 - val_recall: 0.4511 - learning_rate: 5.0000e-04
# Epoch 14/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 115s 662ms/step - accuracy: 0.6339 - loss: 1.0243 - precision: 0.7429 - recall: 0.4569 - val_accuracy: 0.6391 - val_loss: 0.9446 - val_precision: 0.7382 - val_recall: 0.5278 - learning_rate: 5.0000e-04
# Epoch 15/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.6435 - loss: 0.9763 - precision: 0.7503 - recall: 0.5132 - val_accuracy: 0.6644 - val_loss: 0.9398 - val_precision: 0.7438 - val_recall: 0.5582 - learning_rate: 5.0000e-04
# Epoch 16/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.6826 - loss: 0.8835 - precision: 0.7689 - recall: 0.5667 - val_accuracy: 0.6686 - val_loss: 0.9600 - val_precision: 0.7463 - val_recall: 0.5927 - learning_rate: 5.0000e-04
# Epoch 17/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 658ms/step - accuracy: 0.6990 - loss: 0.8351 - precision: 0.7723 - recall: 0.5970 - val_accuracy: 0.3491 - val_loss: 6.1849 - val_precision: 0.3586 - val_recall: 0.2951 - learning_rate: 5.0000e-04
# Epoch 18/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 657ms/step - accuracy: 0.7213 - loss: 0.8174 - precision: 0.7892 - recall: 0.6261 - val_accuracy: 0.6602 - val_loss: 0.9953 - val_precision: 0.7251 - val_recall: 0.6071 - learning_rate: 5.0000e-04
# Epoch 19/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.7561 - loss: 0.7067 - precision: 0.8106 - recall: 0.6869 - val_accuracy: 0.7361 - val_loss: 0.7942 - val_precision: 0.7917 - val_recall: 0.6796 - learning_rate: 2.5000e-04
# Epoch 20/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 660ms/step - accuracy: 0.7907 - loss: 0.6433 - precision: 0.8304 - recall: 0.7244 - val_accuracy: 0.8221 - val_loss: 0.5316 - val_precision: 0.8649 - val_recall: 0.7774 - learning_rate: 2.5000e-04
# Epoch 21/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 658ms/step - accuracy: 0.8273 - loss: 0.5556 - precision: 0.8615 - recall: 0.7684 - val_accuracy: 0.8204 - val_loss: 0.5346 - val_precision: 0.8647 - val_recall: 0.7867 - learning_rate: 2.5000e-04
# Epoch 22/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 658ms/step - accuracy: 0.8310 - loss: 0.5152 - precision: 0.8675 - recall: 0.7893 - val_accuracy: 0.8347 - val_loss: 0.6281 - val_precision: 0.8713 - val_recall: 0.8162 - learning_rate: 2.5000e-04
# Epoch 23/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.8548 - loss: 0.4706 - precision: 0.8839 - recall: 0.8148 - val_accuracy: 0.8508 - val_loss: 0.4642 - val_precision: 0.8759 - val_recall: 0.8272 - learning_rate: 2.5000e-04
# Epoch 24/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.8742 - loss: 0.4107 - precision: 0.8939 - recall: 0.8398 - val_accuracy: 0.8398 - val_loss: 0.4908 - val_precision: 0.8689 - val_recall: 0.8162 - learning_rate: 2.5000e-04
# Epoch 25/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 656ms/step - accuracy: 0.8673 - loss: 0.3988 - precision: 0.8972 - recall: 0.8475 - val_accuracy: 0.8297 - val_loss: 0.5162 - val_precision: 0.8419 - val_recall: 0.8170 - learning_rate: 2.5000e-04
# Epoch 26/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 655ms/step - accuracy: 0.8783 - loss: 0.4081 - precision: 0.9014 - recall: 0.8553 - val_accuracy: 0.8432 - val_loss: 0.5230 - val_precision: 0.8627 - val_recall: 0.8263 - learning_rate: 2.5000e-04
# Epoch 27/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.8969 - loss: 0.3457 - precision: 0.9184 - recall: 0.8695 - val_accuracy: 0.8963 - val_loss: 0.3578 - val_precision: 0.9085 - val_recall: 0.8870 - learning_rate: 1.2500e-04
# Epoch 28/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.9283 - loss: 0.2630 - precision: 0.9399 - recall: 0.9169 - val_accuracy: 0.9022 - val_loss: 0.3426 - val_precision: 0.9118 - val_recall: 0.8895 - learning_rate: 1.2500e-04
# Epoch 29/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.9448 - loss: 0.2229 - precision: 0.9538 - recall: 0.9284 - val_accuracy: 0.8862 - val_loss: 0.3755 - val_precision: 0.8960 - val_recall: 0.8794 - learning_rate: 1.2500e-04
# Epoch 30/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 657ms/step - accuracy: 0.9453 - loss: 0.2040 - precision: 0.9545 - recall: 0.9330 - val_accuracy: 0.8938 - val_loss: 0.3540 - val_precision: 0.9035 - val_recall: 0.8845 - learning_rate: 1.2500e-04
# Epoch 31/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 655ms/step - accuracy: 0.9507 - loss: 0.1894 - precision: 0.9569 - recall: 0.9416 - val_accuracy: 0.8836 - val_loss: 0.3693 - val_precision: 0.8908 - val_recall: 0.8803 - learning_rate: 1.2500e-04
# Epoch 32/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 659ms/step - accuracy: 0.9623 - loss: 0.1613 - precision: 0.9703 - recall: 0.9536 - val_accuracy: 0.8971 - val_loss: 0.3408 - val_precision: 0.9007 - val_recall: 0.8946 - learning_rate: 6.2500e-05
# Epoch 33/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 658ms/step - accuracy: 0.9686 - loss: 0.1435 - precision: 0.9737 - recall: 0.9627 - val_accuracy: 0.8971 - val_loss: 0.3552 - val_precision: 0.9022 - val_recall: 0.8946 - learning_rate: 6.2500e-05
# Epoch 34/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.9774 - loss: 0.1276 - precision: 0.9820 - recall: 0.9681 - val_accuracy: 0.9073 - val_loss: 0.3469 - val_precision: 0.9106 - val_recall: 0.9022 - learning_rate: 6.2500e-05
# Epoch 35/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 657ms/step - accuracy: 0.9831 - loss: 0.1075 - precision: 0.9872 - recall: 0.9765 - val_accuracy: 0.9047 - val_loss: 0.3405 - val_precision: 0.9105 - val_recall: 0.9005 - learning_rate: 6.2500e-05
# Epoch 36/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.9807 - loss: 0.1040 - precision: 0.9830 - recall: 0.9741 - val_accuracy: 0.9089 - val_loss: 0.3494 - val_precision: 0.9140 - val_recall: 0.9047 - learning_rate: 6.2500e-05
# Epoch 37/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 656ms/step - accuracy: 0.9809 - loss: 0.1054 - precision: 0.9838 - recall: 0.9785 - val_accuracy: 0.9030 - val_loss: 0.3459 - val_precision: 0.9049 - val_recall: 0.8988 - learning_rate: 6.2500e-05
# Epoch 38/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.9871 - loss: 0.0904 - precision: 0.9893 - recall: 0.9820 - val_accuracy: 0.9013 - val_loss: 0.3635 - val_precision: 0.9050 - val_recall: 0.8997 - learning_rate: 6.2500e-05
# Epoch 39/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 656ms/step - accuracy: 0.9854 - loss: 0.0853 - precision: 0.9863 - recall: 0.9826 - val_accuracy: 0.9115 - val_loss: 0.3561 - val_precision: 0.9175 - val_recall: 0.9098 - learning_rate: 3.1250e-05
# Epoch 40/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 656ms/step - accuracy: 0.9908 - loss: 0.0737 - precision: 0.9918 - recall: 0.9879 - val_accuracy: 0.9056 - val_loss: 0.3802 - val_precision: 0.9098 - val_recall: 0.9013 - learning_rate: 3.1250e-05
# Epoch 41/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 113s 656ms/step - accuracy: 0.9912 - loss: 0.0677 - precision: 0.9933 - recall: 0.9898 - val_accuracy: 0.9140 - val_loss: 0.3615 - val_precision: 0.9186 - val_recall: 0.9132 - learning_rate: 3.1250e-05
# Epoch 42/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 658ms/step - accuracy: 0.9918 - loss: 0.0663 - precision: 0.9924 - recall: 0.9871 - val_accuracy: 0.9089 - val_loss: 0.3593 - val_precision: 0.9149 - val_recall: 0.9064 - learning_rate: 1.5625e-05
# Epoch 43/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 114s 657ms/step - accuracy: 0.9923 - loss: 0.0641 - precision: 0.9941 - recall: 0.9900 - val_accuracy: 0.9123 - val_loss: 0.3531 - val_precision: 0.9145 - val_recall: 0.9106 - learning_rate: 1.5625e-05
# Epoch 44/50
# 173/173 ━━━━━━━━━━━━━━━━━━━━